# %%
import os
import shutil
from collections import Counter

# 원본 폴더 경로
paths = ["./origindata/valid/", "./origindata/train/", "./origindata/test/"]

# 처리된 데이터를 저장할 폴더 경로
output_labels_folder = "./data/labels/"
output_images_folder = "./data/images/"

# 클래스 이름 목록 (인덱스에 따라 매칭)
class_names = [
    "red", "yellow", "green", "stop_sign", 
    "40_sign", "80_sign", "start_sign", "person", "others"
]

# 클래스별 카운트 초기화
class_counts = {name: 0 for name in class_names}

# 삭제 대상 클래스
delete_classes = {"2", "3", "4", "5", "6", "7", "9", "10", "11", "13"}

# 새로운 폴더 생성
os.makedirs(output_labels_folder, exist_ok=True)
os.makedirs(output_images_folder, exist_ok=True)

# 데이터 처리
for path in paths:
    # 원본 폴더 경로
    labels_folder = os.path.join(path, "labels")
    images_folder = os.path.join(path, "images")

    # labels 폴더에서 모든 txt 파일을 순회
    for filename in os.listdir(labels_folder):
        if filename.endswith(".txt"):
            txt_path = os.path.join(labels_folder, filename)
            modified_lines = []
            class_counter = Counter()  # 클래스 빈도 카운터

            # txt 파일의 모든 줄 읽기
            with open(txt_path, "r") as file:
                lines = file.readlines()  # 모든 줄 읽기
                for line in lines:
                    parts = line.strip().split()
                    if parts:  # 비어 있지 않은 라인만 처리
                        if parts[0] in delete_classes:
                            continue  # 삭제 대상 클래스 줄은 저장하지 않음
                        elif parts[0] == "0":
                            parts[0] = "2"
                        elif parts[0] == "1":
                            parts[0] = "0"
                        elif parts[0] == "8":
                            parts[0] = "4"
                        elif parts[0] == "12":
                            parts[0] = "5"
                        elif parts[0] == "14":
                            parts[0] = "3"

                        # 클래스 카운트
                        class_counter[parts[0]] += 1
                        modified_lines.append(" ".join(parts))

            if not modified_lines:
                # 모든 줄이 삭제 대상 클래스였던 경우
                image_path = os.path.join(images_folder, filename.replace(".txt", ".jpg"))
                if os.path.exists(image_path):
                    os.remove(image_path)
                os.remove(txt_path)
                print(f"Deleted file (all lines matched delete_classes): {txt_path}")
            else:
                # 가장 빈도가 높은 클래스 찾기
                if class_counter:
                    most_common_class, _ = class_counter.most_common(1)[0]
                    image_class = class_names[int(most_common_class)]

                    # 클래스별 카운트를 증가시키며 파일 이름 생성
                    class_counts[image_class] += 1
                    new_image_name = f"{image_class}_{class_counts[image_class]:05d}"

                    # 텍스트 파일 복사본에 저장
                    output_txt_path = os.path.join(output_labels_folder, f"{new_image_name}.txt")
                    with open(output_txt_path, "w") as file:
                        file.write("\n".join(modified_lines) + "\n")

                    # 이미지 파일 복사 및 이름 변경
                    image_path = os.path.join(images_folder, filename.replace(".txt", ".jpg"))
                    output_image_path = os.path.join(output_images_folder, f"{new_image_name}.jpg")
                    if os.path.exists(image_path):
                        shutil.copy2(image_path, output_image_path)

# 결과 출력
print("Class Counts by Index:", class_counts)
# Out:
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000001_jpg.rf.5eb4f984823b1a44afc9bf98804daa50.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000002_jpg.rf.d65ebeef4d1cb26e3fc1a826770b729f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000004_jpg.rf.00126fe7725236ec5dc849bac78543c2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00002_png.rf.109f031ac8e60eba952da43b054389c0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00003_png.rf.e1d0c6904cad2c27548ec3c332b2e088.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00008_png.rf.823f2aa00055169915d8979d389796eb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00010_png.rf.ea7f6dcad45043cc1275a3722f259c45.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00011_png.rf.d273eb7959d82848c1bbf816e503a7cc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00016_png.rf.501890d4ac7f8422f349833245d7abc0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00017_png.rf.af8c4a23f87c883e6c718be719d78834.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00019_png.rf.5e0626fb5f6c03e2137b454192d1a6ea.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00023_png.rf.ba3c9472391c55dddbea2b609d7c95ef.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00024_png.rf.b7b5b6753ff94db8b6ad0904043f5c47.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00000_00028_png.rf.79164ee5db8dd374dee79d309ae3276d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00001_png.rf.0a5c9b8c2585b556bb0176c33d8ba594.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00004_png.rf.6bcd3ab2c19f9e4ed176d96f7f73e084.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00005_png.rf.39fe79ecb0b552859813e4daf4a2edc2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00009_png.rf.841cc50cd27e97581eb6d0234bc4bb46.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00014_png.rf.f4a23099ee55a117ddbdf614f0060111.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00015_png.rf.38a3cfcf656efbce048431b7df469837.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00017_png.rf.2512e4fa7c72637e03252940dd911882.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00019_png.rf.7df817b331a58bfe6f42b04b59ffee4b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00022_png.rf.86a6404cd77a9c80b0cc735b19b763cb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00001_00023_png.rf.ad5e845504342a9c0c6a4c734e99f8f2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00002_00000_png.rf.a6b7c53f9c779067be91c4d331bed12d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00002_00006_png.rf.38607fba142760f6d61a8806ae748fcc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00002_00014_png.rf.851465423d63cf26575590f762af5c2b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00002_00029_png.rf.f584d2f610afde0abb821fe96a348203.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00002_png.rf.76d9ce9f361d1b20eb1b0d5c4d9356b7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00002_png.rf.e634a332d201c84f03eac04d4a8b22ee.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00008_png.rf.374fb6d685cf80341eced8c159f48659.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00010_png.rf.8d0b8153b699be93838f2ab1adb3c5f5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00012_png.rf.246a45eeb77623d43d7d35292c01e488.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00016_png.rf.119a4465c771266fa404e7bbbcb718cd.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00020_png.rf.92fbe7c2ac68b3f455aada3b8b02aa12.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00028_png.rf.0be3aff7a8d535bb23aed121db9871f4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00003_00028_png.rf.5b6b19270267f8aa19060cc871d01b54.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00004_00000_png.rf.2035c6eac81cf733715d605be8b19a3d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00004_00023_png.rf.e766ea5b2f7fb6f86cb29bb721ef7120.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00004_png.rf.3b1da84bffee4d187959b6d9fa49ef41.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00004_png.rf.e5420c1cd4e614fb9a0c6bad2967f7ae.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00006_png.rf.74594564734029824f07e7ec6f437ffa.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00007_png.rf.f035d5f40157b6e8ad96e569ab3c8dbf.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00016_png.rf.868eac740114de5a72281450cae54d4b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00018_png.rf.20ae5dc6f9775df0c040611697a1f4a4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00019_png.rf.5c7911d1c82f2a8974b1476efab21a32.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00021_png.rf.69bd0c31c470a36e351d9bf107e017db.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00005_00022_png.rf.6e64e5ed69bbf31356e5329842003956.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00006_00004_png.rf.49287ea2187ee3e2492f3490bea0b932.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00006_00005_png.rf.80f7b8a9aa386fad4e88deb0751d44db.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00006_00008_png.rf.6e64e50bce5346d9caec663b34ee71b3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00006_00017_png.rf.66c94793170aa8f8054e5832ce0305e0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00000_00006_00023_png.rf.4c75431aed70e19f6bd3c2f5ccf07391.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000011_jpg.rf.fa32ab1ecb9f791f607dcaecb05a8dd7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000013_jpg.rf.c2947bdf01306795dc799928eec4c157.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000016_jpg.rf.f4568240f9384349bcefdd70e594b519.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00004_00003_png.rf.806b4f93884a4afa323c90f720993988.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00004_00017_png.rf.59c17684b246375c90a66c80185ac3f6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00005_00008_png.rf.40d0da91ea6cc55d098dfc3e32176ed4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00006_00002_png.rf.96807e7b1631778e556feedd6982218b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00007_00010_png.rf.3b97ab40ade2235e54b1cd674fd40148.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00011_00007_png.rf.5a1e3a0bff0fdeddae8d3884cc1d0a55.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00019_00018_png.rf.8317748f9fc7b4fb05cd6370b0c409fa.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00020_00012_png.rf.0c2732ec2a3ed93214b1e41395ad7a2b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00023_00025_png.rf.2626b0368405fa35ce5519d212ab019c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00024_00015_png.rf.27b7f5a37c32be10469b7fb9e6859a54.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00024_00019_png.rf.201dbcf518f485213be0896d36c866f2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00025_00010_png.rf.4647a0ab875d1ff161faaeb4eef72b27.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00025_00021_png.rf.71e8b5a711e8a7d62315c724fdf9e61b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00028_00009_png.rf.d3776cc5b7ff2e6f019157bcde378ab7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00030_00007_png.rf.97236f8f38630a2e52d58e3e34c9adce.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00031_00010_png.rf.3117240f6b207aa89ea9e14bb8f93e58.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00031_00012_png.rf.51847911c211fcbfe57fb26f390b07c0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00034_00017_png.rf.6ba1b8dfc5d3a83dfc305f8421532d46.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00037_00009_png.rf.98442136f1fcf52990902250291c48e9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00037_00018_png.rf.fdbd3c3ecaa77be61cff73f08ee1dbba.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00040_00008_png.rf.5f47667bf822034a38b87b869d4996a0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00041_00006_png.rf.492993b80ba8dce4cc3c8ba55b79cb31.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00056_00005_png.rf.e3e2afe6d8714eeb65b9fe81bffb8533.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00056_00007_png.rf.2be0d27329c93a51dbec70f7f6936811.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00059_00001_png.rf.f0c4ab06e4825e6f85bd1aa7045bf7c2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00066_00005_png.rf.b88a1804a44f6e513c39d3119d72baee.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00066_00018_png.rf.ea5065ed23c168fe2b63e7a8f5d839c1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00067_00009_png.rf.ae479bfc362a2451572b0f16535561b0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00067_00010_png.rf.90dbae774974b5231715ab3e1c331c14.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00068_00006_png.rf.cdc0829f9edf6c7730f639bede108a4e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00001_00070_00012_png.rf.eba0ec2077e1a2951e7ba846ebc3f97d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000020_jpg.rf.2f0901cbff62fb4830e39d5d5e46ad39.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000023_jpg.rf.147364eb3bc656deef873e1f9aadefa3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000025_jpg.rf.0159a012742956804d362365998132f7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00000_00021_png.rf.e68063086859a10db07ea12c37e52199.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00002_00006_png.rf.a5efd17b8611e692e8bce402eb3b86b0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00002_00026_png.rf.574b361bdf1b724030164ec780ca3236.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00002_00028_png.rf.f65c7aefe974cd45269be85afb390fe7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00004_00026_png.rf.e08350cc250857c28ec1d619fb871d07.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00006_00029_png.rf.9f80d940730690b080db3edd9104061a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00009_00017_png.rf.76cbe36edd72f8ef05c8a7e1de7d9c2f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00011_00029_png.rf.9218bf68489dd27976848d871cf32f46.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00012_00006_png.rf.ca4aa072eaf5140582e14ec592965ae9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00013_00002_png.rf.0b6b2e77383558449f4125d32e7becd9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00013_00023_png.rf.9b31982d2f94e015a3503264b93e4600.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00015_00006_png.rf.f6af83f098bc43372267a8b09ca2ac72.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00016_00000_png.rf.ef183ee432de2051a6b4ff73403c80bc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00016_00013_png.rf.6797ade511dd2424faa33b9196d1cf99.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00016_00027_png.rf.6866b3121b0123e588a02636ca208327.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00017_00018_png.rf.3676c5aa3568ba151f34e4ad83d09a64.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00017_00021_png.rf.d4e4ad4ccd7d778cda3fc4ac17f529c9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00018_00000_png.rf.608f86a34161113cb45149b33031cb4f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00018_00001_png.rf.75fb22aa5736d01cc75f5912c53053c1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00021_00028_png.rf.b711e3eec093c14ad18a15ace24cc815.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00027_00010_png.rf.2e542ec2b9951cb11b3bddb90a4bcddb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00027_00019_png.rf.b798b0fad245406428697baf06fd08aa.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00029_00005_png.rf.eaf3386241d4b3d165ad5cfeed05f96e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00029_00021_png.rf.6e0a766751a8611b5eb9bf075a5843db.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00031_00007_png.rf.2b1ddc8b14e995d413eafed07739926e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00031_00028_png.rf.6f071d23e04f044981310d02000cc630.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00033_00004_png.rf.aa287dc137abb93255fa4c9d696194f6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00037_00001_png.rf.8763a480932d750a7496967ab0999e74.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00048_00009_png.rf.bafb9b075eadadd9edfe89f23849a7e5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00049_00024_png.rf.d6d53dd4d97ad0df6b6357f012c469ed.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00057_00021_png.rf.1ca1fbfd6dcae355f8469f0221f1d159.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00060_00001_png.rf.5d26ce504b606a49ce1b84dfc60c16fe.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00060_00002_png.rf.c9453cdcd9cbf502cec8a641ce9206ea.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00062_00005_png.rf.e032b40ea2327e5c2522ded913581b61.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00062_00007_png.rf.bbbfeb397f679491ec7c5afad46b958b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00002_00065_00024_png.rf.c42fdae251687a0ea3eba77d62fd105f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00001_00000_png.rf.9ed87fda908a3a802ab6918948970e61.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00001_00005_png.rf.0c1e1a51e170ad308abedbe84f02c954.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00005_00022_png.rf.ea4191f4b55acfb59bf2389f6d5c81a0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00006_00004_png.rf.934b80a45c2f27e2f8053eb0597e14b7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00006_00022_png.rf.256efc029550f2940ca77830d7aa592a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00008_00014_png.rf.bc438c08293706efb7e21473f833f347.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00008_00025_png.rf.b1a1fa00721f04de200e73e4f1d406c5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00010_00005_png.rf.c28982830ad4bbb1e85c775fd4fd74ab.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00010_00014_png.rf.b45d97663ce35d1dfae8d929214f77df.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00010_00019_png.rf.8e7af71bda1f7de88bc25e3f61a3872c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00012_00019_png.rf.4ada5352563505194f6673d0f4e5801c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00012_00029_png.rf.2ea12a5b8b7584c163b616b486ad7f0f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00013_00012_png.rf.9f4054c3d3f2b40ddede90c45488de0c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00013_00014_png.rf.9ff8cb79d782ed1d941f680d39b47778.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00017_00005_png.rf.8b51eeea8ed4ab5ea5dad2a8f04ab9f0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00017_00016_png.rf.db4aa89aae2c148c876478f7395a022d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00018_00028_png.rf.179f37d955eda91d6686773dfedb9c9a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00021_00005_png.rf.287ee836bcf546b036a09963d6a2b7b3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00021_00016_png.rf.5c5d67a5464d3c8b438b2f4afb5cb50c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00022_00017_png.rf.72237bd37718f6617168aea46911de7e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00022_00028_png.rf.279bbf36c217edc1467ef0d3ad614fe9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00023_00020_png.rf.97eecd71bf949e1de4c632665440355c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00028_00007_png.rf.8207c89bad9f7e0d066c7c03da570439.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00028_00008_png.rf.ce6054a0b8c643ccd050227e8ae86c4b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00028_00014_png.rf.5b49845bc97aba9a158163dec51c427a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00030_00021_png.rf.8c5ff79679325b3e5d05f86658aabce8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00031_00013_png.rf.4733a9e4d58808f8c35303ae7284eeb7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00034_00002_png.rf.dcdeec740ea7f3799d5800dbadcf85b7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00034_00019_png.rf.0de3d19e5692bce58ecddbf047332432.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00034_00026_png.rf.52c367d3b30c37774b24845872eaf9f1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00035_00020_png.rf.0fbe31b3b39556f7dbdd6c492a67d31c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00035_00024_png.rf.bb232297191447d6ef46628ab901b5ee.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00035_00027_png.rf.e7a890e41b9463dc363fd277f4bf097c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00036_00004_png.rf.56cba09f9f7eb88f7b6536c58b008bf7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00037_00023_png.rf.8d681fb18eb715ff4f3dc46fe6e29053.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00038_00016_png.rf.9b8614e4a9dac36a613705224fb26166.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00040_00007_png.rf.8d2e5b040a703955ee06dc5308ed92f5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00040_00029_png.rf.8756d0c519b7d7285532e9231628c3be.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00042_00026_png.rf.764f9b67eae13c366b8ec322311c11d7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00043_00025_png.rf.8125ce506ae33530b205dd082bce1800.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00044_00004_png.rf.5c7867c6d2ff799a45687ff6cb5abf3f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00044_00011_png.rf.30ce8436a483288f93160f1ad678d43e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00044_00012_png.rf.b3b50faa0f7bfe1d5e9051e3f63f4616.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00045_00007_png.rf.21c04f5100d639bb7e0a0818432e8946.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00045_00010_png.rf.2e43861bfe4173b95baf7dc50d342195.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00045_00023_png.rf.00e371c5ff30f5a41eb54a54f93b9133.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00046_00012_png.rf.d370d6be4e7c3f714005f47147137d7c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00046_00015_png.rf.ea1b6ec52a5ecf660e1fd090cf2cf017.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00003_00046_00019_png.rf.288895bbd27718d25e2a21ac3cb01fc5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000044_jpg.rf.20e3e55d0fc80a8a786d2ab7bbca7ef5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000047_jpg.rf.3da4d486d7b29ef66899b32813c47247.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00001_00003_png.rf.7b725e8e9c1d1cf38d34956d1c018698.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00002_00011_png.rf.25821bc19233fecf56cc9accd1e443a5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00002_00022_png.rf.6e9d8becdbd4b8c9ce6bd313669a42b0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00003_00027_png.rf.2e091c6dd85c5b454c15803ecd89dbe0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00005_00020_png.rf.99f078a477ad303400db1b5f9055a783.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00006_00004_png.rf.ed2da1afd871c5e02698621ef8f2b1a7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00007_00005_png.rf.e9f4d8577e3326a259ba0cf498487a86.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00007_00019_png.rf.1f467b1dc5421ed245ea1afe63b8eadb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00009_00006_png.rf.c5f118e8cdbaff0966fc3fed1d9011c4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00010_00009_png.rf.f92a420ca856ad882526c659d8279110.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00012_00001_png.rf.ab3cd39cc76f70b5cf8a7284bc5a50bb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00017_00006_png.rf.b8e67c538a069566238d9fb824da0119.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00017_00008_png.rf.56e9079ebf0bcdafe18c38a0ffad8546.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00018_00007_png.rf.baa3ce2259b88b7bb8f7e787470833a7.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00020_00013_png.rf.51cae997b14fbcdb99df8678aa0971f2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00020_00025_png.rf.b9a631f815ef28fe0dc578ced6040ddc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00022_00001_png.rf.0016065be6c29d3cda0a166606e9876b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00022_00011_png.rf.b01709656ae6b82ba3aa54b30bfb7ed3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00027_00008_png.rf.e96cf71c48a64a96521a7196b8833bb5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00031_00016_png.rf.277579adb28552506e9079d544150dcd.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00031_00027_png.rf.c3258ead2ad5fd6d61e71052c15139b4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00032_00016_png.rf.7e862722fbecd57018664c47c3592b41.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00034_00009_png.rf.dbc730c2a7f5badb19b9ba2f65a0c7f0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00036_00006_png.rf.bb9c39f8275d860fc51fadc5f693e633.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00036_00013_png.rf.78743043707fe91f1cb89a6b93142b7c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00036_00027_png.rf.18f4dc5c0e4c411d61b6113cf2d5a166.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00037_00006_png.rf.859172c0751de35fe695683661bc5f5c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00037_00010_png.rf.2d548b82f656367528a9b69d5b6b82cf.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00037_00019_png.rf.075b9e62e480ce017c3b8e0284435ba6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00038_00009_png.rf.7c89ed5f7a3cacf3be0eba60e006f66d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00038_00015_png.rf.fa07f671f1547c2d5553bc88cbc68eac.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00038_00020_png.rf.e3dac76ad990b48503995b5e1c9da8e5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00040_00006_png.rf.0df4700578f74f73aa0d5aa6e6818e8d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00040_00017_png.rf.f3406cb8a1c43a4d3ed5fa37af0b389f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00040_00018_png.rf.79323a962d316e1b7a085819f450ed9d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00040_00021_png.rf.fc113b962d26c47d3dc5df9304970723.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00042_00011_png.rf.c403db526195c4c2ded00bc82c875655.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00042_00022_png.rf.57fc6d356c7942d39777605ee8ef8b6a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00043_00017_png.rf.8576320ec474292e4d12ecb40e479a7e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00043_00028_png.rf.0f8a94b02eeeb2bcd58b633c57c305a1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00045_00020_png.rf.fe4cc87adb689ee9cf551c0263265443.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00045_00021_png.rf.70e25231968f91d6246de485d6d019dc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00046_00023_png.rf.0b32f721688e82fcf824071c45152147.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00048_00027_png.rf.64eabc2b921a3e805278cce486f9416e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00049_00019_png.rf.bdf40d4ddc1d2c2815c0500456553572.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00051_00023_png.rf.dde86b9f99927dfe07d283b4a78b05b4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00052_00013_png.rf.f59d46c5c83b32b25ea452ccd41d6a67.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00059_00015_png.rf.eabd0acc596d06455c79486b3d3cb57d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00060_00008_png.rf.f3ad27b4d05355b22056c389122a9ac6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00060_00019_png.rf.db5c6fc5db3eaa43c08496dd225a7393.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00061_00010_png.rf.4d35a113f2b70c2d0e82add786cef442.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00061_00013_png.rf.c34fb537a9a7faeb1a32512065323deb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00004_00061_00021_png.rf.9cb0d56d97d26768b1e2a21c7e25b32e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000054_jpg.rf.ebe63c651dd9d1143e798d62488e1226.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000056_jpg.rf.1a02a221cd346c0662c7fed02b958ad4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000058_jpg.rf.c4c6678dfa93ff09c11d7e99ef920eaf.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000059_jpg.rf.b190180521e9edd87152a789fadf42d9.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000060_jpg.rf.8f2d5e4e877e2b6e5b3c824d2bec3115.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000061_jpg.rf.89000fe381cd875949055c02e0e05f44.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000062_jpg.rf.cc95cfe9c2ec51e7e600b32dad431408.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000063_jpg.rf.09edd7ea94dce4652230cbf71443c9f5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000075_jpg.rf.0e1ccee9ff9e03910cf3b1147527d382.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00000_00007_png.rf.037d8a9398bfad6b4623c9405a73cf86.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00002_00009_png.rf.113c0ba0b62a55eca6dc6f2f37297407.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00002_00011_png.rf.3e6ecd510efe187683f4efffca1642f0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00003_00010_png.rf.2422eb69afa6d9c8b5b1a119b9c54050.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00003_00016_png.rf.e834e42b95e08079227b43e7d21c3266.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00005_00009_png.rf.72ca74c87701450c3a853aa29282e9e8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00010_00025_png.rf.fc51afae341a552a3e500aa8e4bb35d6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00010_00027_png.rf.314ddd042a9379af387466446c01f99a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00012_00026_png.rf.3e2a58c5d3fe9c62d6b1dada42f9fa0c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00017_00021_png.rf.2fbaf2e83a780499bc494ec32a0ca177.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00018_00016_png.rf.f58ce7ada8acdd2a4fa44640bbfdcfc8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00024_00003_png.rf.01cdf4a32b745a4112bdf4c76b8660da.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00036_00022_png.rf.a279bc5e70d68ee42f455ea24381b187.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00003_png.rf.e6c316b3ff0c7bd0cf468489312dc39a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00007_png.rf.281728de5200a94e5f62a38231f65e1c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00010_png.rf.ec421c2923817221ce994e6e8089dbd0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00012_png.rf.0c1127f500a7607cfed5a49bc2893b4d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00016_png.rf.a69af6b943838b941eae692d6c8f59c2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00021_png.rf.101bac056abedcfc836ec4014564cbe1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00041_00026_png.rf.ad63b790aad9f888863f251dc4b275fa.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00042_00014_png.rf.f302d8ba353590e1ec60b91d228a0304.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00042_00022_png.rf.ebd1d9a4e17869923212c3da7fd54df2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00045_00028_png.rf.901c4d935d8ee61b03500b16f3143a79.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00007_00045_00029_png.rf.c9fba3ded9cf373c1547666a4b854fa8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000087_jpg.rf.474f8ec5ba0ca63e725cca0733d021bc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00000_00009_png.rf.e246e29599a3b358fb9a9911303a0911.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00000_00025_png.rf.54a2c7bed1c4f555a5825fa8b3dd2c7b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00004_00013_png.rf.edd68f6e8950651f15f3e4eb2e59de25.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00004_00014_png.rf.3d0e2403e5816d9e4cddffeab959d91d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00004_00018_png.rf.d04b1e5cf05ad80902d307cc7e6c431d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00005_00016_png.rf.0dc3f1206158857c75c6ad29d422dd99.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00006_00019_png.rf.9284ba138dea764af54bb1429aeb31ba.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00007_00012_png.rf.c3d898d938b7deebab53bb896fe22d9b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00008_00019_png.rf.8251d851ef8cfe67c02a3fe47e2b2c43.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00008_00020_png.rf.6c66ef0dde590ac7dfddb8a715bd57ac.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00011_00001_png.rf.552d1ac62d4fbb2d8d76f528f3b8f610.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00011_00026_png.rf.d48e07f968b239bc5c2f8e3cbade525d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00012_00004_png.rf.901d50a564943436405ece8251824e2b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00012_00013_png.rf.a1d09d94107a2bc2391b90cc813f036b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00012_00015_png.rf.10d59dd6e0409c272fbeac276a01daec.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00012_00026_png.rf.9d73f6bf08134cd2d6f1cee81cc97d44.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00013_00010_png.rf.8c734c3859b581451b57c485582f5ce6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00015_00022_png.rf.8df6ca081651930cffd22c46186837bb.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00015_00023_png.rf.d08260bc4588dcab6fe5b54989e91502.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00017_00021_png.rf.e3539348f10ebb2a43c22c2ff8ead631.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00018_00023_png.rf.2a857f20235cc46664627e09b7a58409.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00024_00015_png.rf.0a488e624b482b0c2c96148cbc582449.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00032_00019_png.rf.ae03f2835ae96130daf7dbb29da57225.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00034_00010_png.rf.c63f6f9720ff1a0ecf10ebfb55844f2d.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00038_00008_png.rf.2a7a8fd66cf9b684e26801ef89447731.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00038_00009_png.rf.12ba1188789e6b6747031686b0576a20.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00038_00010_png.rf.4c9c38b445211d75ca18a1e49d3f7c7b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00039_00022_png.rf.5fa7f0b9ebfa8a702336246e92f63e2c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00044_00020_png.rf.b7f1da92ed0f5a60d3c31f13f4ea524c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00045_00004_png.rf.311591d23c3c9bc5e4f148c5d4c3198b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00045_00007_png.rf.8baff974a77b214a7291a7414715353a.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00046_00016_png.rf.8b23be6230e702bfc05f412016444393.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\00008_00046_00026_png.rf.4132e5229d03953696029788c0d7377f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000092_jpg.rf.87588aa3b0f60afb13c9c0a0575693f6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000093_jpg.rf.b807d4d48b8504ef32c8092be695ab21.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000098_jpg.rf.4b8be686f943aa7349065e09d710dfa3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000104_jpg.rf.84bfd7deb7e3d5f06dc8284e8c40b521.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000111_jpg.rf.e60c5cd270ea82c644bdfc2ee629daef.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000123_jpg.rf.d05325e5ae61a1b2cf969df6389c899c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000131_jpg.rf.d5b08b4a7d3727786a522ed886d962e6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000137_jpg.rf.4417be60e5e8d0047af644d961795c36.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000140_jpg.rf.e9eafc934e46f0cd62b6e05d4c614d79.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000149_jpg.rf.b30519cf48fdf6e879c724a7e5a3d24c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000154_jpg.rf.10e8182b19d397c1a3fc5496f48956c6.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000158_jpg.rf.de2717752337de37af3909a837ac1ecd.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000159_jpg.rf.1453deeb1721dd612b3e4c6ec33da5d8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000160_jpg.rf.63f912a8062e2c8868e97ab5fd14d647.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000161_jpg.rf.ae64f76d8ef6076b247838f85e05de8f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000164_jpg.rf.4299a2cf7fe633528bda8e6c82bba7e0.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000165_jpg.rf.e9dabfaaf12417e2ba0ac7ec3127c251.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000176_jpg.rf.96cf6ceea532f7e4169a4cea717a6219.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000187_jpg.rf.a4e0eb7a38e4d4cadcef43e381a0f033.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000197_jpg.rf.c3fc560c02bac1c6baeec423405f5c24.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000311_jpg.rf.92fb3e611aa56284af5fd4765e5368d3.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000319_jpg.rf.1fd32a8ec85d8ece29bdcc792fdf960c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000320_jpg.rf.62b5a7f335fc5e0c633774c04d7d7088.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000330_jpg.rf.e8b0af092d57c4f34925bb7177a0b474.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000339_jpg.rf.09a46fe4f8a60c2703ab35a8d982461e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000348_jpg.rf.df4749301a69a49513ab3c77b76c6ba5.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000352_jpg.rf.d63e34658183df08ad20ef345a34795f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000353_jpg.rf.9da320bfbb4f4b6d2ec25b69a0be7f06.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000354_jpg.rf.b7ccfe0e9fd239ec28a6518202c7c531.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000363_jpg.rf.ed6453a9c64ca832ebf1b36aa5a50907.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000371_jpg.rf.d2f84e3f3e15cea3038a66be160e894f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000373_jpg.rf.f6a0fe844051159b218ed37511a14a7c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000387_jpg.rf.7119e3f9c6a97ec54b1de9f62fd6f7b2.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000394_jpg.rf.207625ae162416a9c54677d3dfb6e111.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000399_jpg.rf.db38c5d43dc8f412c03578dbabae5d19.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000401_jpg.rf.d08904263e901566fa23580df75bfd52.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000413_jpg.rf.669b3ac51f4fee4f4df7766754610121.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000420_jpg.rf.0f91560519dbea3e36a02a20f10ec48b.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000432_jpg.rf.24bdf904d16f60471490456f826ee193.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000434_jpg.rf.10ecc3b6b80b17f6792a4fb7939437ca.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000435_jpg.rf.14bc5d69fce5237cc7bf63668f861345.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000437_png_jpg.rf.5be9f4fe4b3f2ebc8ed2954d09d791bf.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000450_jpg.rf.8dbe8ff0fd011220d307b9d8fe745323.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000456_jpg.rf.afad59663b563575264001ee039d2168.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000460_jpg.rf.3be56562d86269ad806603bb1cdb710c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000461_jpg.rf.beeb2bc233e2f5893d128e0a7eea18d8.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000463_png_jpg.rf.90ac8516e2d1a9a7999901c883dcd2a1.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000470_jpg.rf.c46a76f9f37d561bd7021182dad60a4c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000471_jpg.rf.7cff1942730924579c87c484642b6e9f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000474_jpg.rf.f9faa49f328b0810666ae1103e819a7f.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000476_jpg.rf.20e99f8a70b94c7a71d36cde8c333ec4.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000491_jpg.rf.c237338f2d048f5f0326a2d4156ec65c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000492_jpg.rf.378175376b4c76fbf8bf8cb71c5a983c.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000498_jpg.rf.3a2dc5e243040ff3b2584564a411d3dc.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000516_jpg.rf.b0df60d28c0403cd3d0d8a2f9bcd2506.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000520_jpg.rf.6f0a4003fe39cb3f49af95be8b3e4955.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000521_jpg.rf.0deed514852fbf84e58eea8289f5339e.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000525_jpg.rf.b6c20ac9c71c2b22aa23509053f69b84.txt
# Deleted file (all lines matched delete_classes): ./origindata/valid/labels\000707_jpg.rf.425d3bbda0d5bfb0e541cdfb6631d8a4.txt
# ...
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000514_jpg.rf.b0d6f6a9a9a1c36ac223b9185a3cfed6.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000534_jpg.rf.fc7a9c184c96044637a59a8abbc842d2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000700_jpg.rf.4abc8faa3c8f0970d53095fa9218cf8a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000703_jpg.rf.2999e1a86a880c30b97644b227648d36.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000711_jpg.rf.0a584e00809f5da1be911472ba1f8e7b.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000713_jpg.rf.ea540b12ec46dd3f2dad786ab321c3a3.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000735_jpg.rf.8927d1a7914f3b404d59d7afb8238ce4.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000736_jpg.rf.228d17ea85d8e4b2f1fd5a1fec7582d9.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000741_jpg.rf.48077831b42aa2a01691cd30be5da048.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000753_jpg.rf.23d05489386c3399c5d26ac779015d26.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000762_jpg.rf.ea6102293c9b38d9f90158f1a4cc33f7.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000763_jpg.rf.6018d10dd3889ec0579a386c052fb6ff.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000769_jpg.rf.1df4a76b3e7055f19fd63f71a3d4ab3f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000783_jpg.rf.0f12070feb6f7bc91c48aa93a65d2e93.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000786_jpg.rf.60798d12643d9be450731115c76bd86c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000790_jpg.rf.ddb1d679830f7cafbcbec2013a6ff2fc.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000797_jpg.rf.3d78d9d11140e03357ddde30e7e7e98e.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000822_jpg.rf.63b8e6ec737487b4e7e9e2ed48754226.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000831_jpg.rf.09392428bf69f0de8c937caec3590319.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000833_jpg.rf.a774fb7c4620c050e43d66a0062137af.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000836_jpg.rf.c262dc2f875c2d27c5358091bec7f23c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\000841_jpg.rf.82ac37a263cc3771094f878f75519d3c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001000_jpg.rf.55d2c5392c587e099e386a6406bff14f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001004_jpg.rf.b5403b891cecfc5231ff9ef14b3534ae.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001014_jpg.rf.b5f73c9eb6dc1a27fd9ec0323fb5d210.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001023_jpg.rf.f7de58bb03c2e2a346432baa358b4c3e.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001028_jpg.rf.7a77036407cf037c2415b436fde7826b.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001031_jpg.rf.2b5fd42d6b8a7d445183a468803e57b9.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001035_jpg.rf.8bb44e874531b88eb7bdff9082c78a43.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001057_jpg.rf.0d8f858b7a9c12830691348e2ae306af.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001059_jpg.rf.2b325fd15e28d0c622610dea63c2c12f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001082_jpg.rf.6b7fc1c9648c1a3494a137ffa3664be1.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001089_jpg.rf.004c591c5855cf05e2198a5e21c8ab56.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001097_jpg.rf.76b13f1ce839d7102e9a683f6959a3e6.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001214_jpg.rf.85dbeddc5609d79293b1f979131a9f35.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001223_jpg.rf.cd973e1db0f78ec16c70d7af43fc4511.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001228_jpg.rf.f4f7bc0b74a46e26c75aed78c39b41e5.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001229_jpg.rf.3174ec6dbfe9e8ee6ab16906d969ae8d.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001247_jpg.rf.986fd924de123c95a8e6bbcc765d4c10.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001250_jpg.rf.157a04c81cbb47009538b4880d0004c9.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001256_jpg.rf.204fbb92b5dc59d697bf04b2682485e2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001259_jpg.rf.b55c7e7dacc1e607f8e69b2a5cc36568.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001261_jpg.rf.7b5bf5841b26d8966d6081fbc704dbf7.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001277_jpg.rf.03beffa81aa901c8462dfe1681a202f4.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001281_jpg.rf.b8a22407e4c52a0704d45a8b32965f9b.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001289_jpg.rf.2b57939adb36b165f0eef0a3de68e1ec.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001290_jpg.rf.d3a396f3ea066c80a6e76a48dcf798a2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001291_jpg.rf.c0ea8c600fa9219527f23947a8f0e7ec.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001295_jpg.rf.449090465a44f9f98a47e1141f3a8f38.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001407_jpg.rf.70ca057de423bef18930dd5f47b975d7.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001409_jpg.rf.03a314500608050ad90ed1c849fb18db.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001427_jpg.rf.fe832db13f19311c2eda0b6e83878ec5.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001432_jpg.rf.5d8fff00f092a9bcb15a018a3edb186b.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001436_jpg.rf.cc8f571352da66682260166ac2086168.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001449_jpg.rf.4b8f2718b90c8c6cf89ccf753d5b575a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001462_jpg.rf.590c8b4c74096f768de4433951995545.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001465_jpg.rf.82e271056e453a4f123033b7db486d63.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001472_jpg.rf.38654b39e5bc13159c16952df2ba2dc0.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001477_jpg.rf.170667884b322b9985bcd6a054a0d6be.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001478_jpg.rf.b4a8c8adb59b1bfeb056f275a7e9c785.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001479_jpg.rf.61b4e3eab9b3daa20c770dafec663c97.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001482_jpg.rf.c040f508e60b3a870f5f5fc8b9b017d2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001484_jpg.rf.6b44f8da037b210cdbe0663683d7274e.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001494_jpg.rf.4db0ef3199baad5258c353573bffed4a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\001918_jpg.rf.cf4263574ace70aef2c9045b9cde5a85.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00012_png.rf.72d6e678caad674f4fe8c948471cf743.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00018_png.rf.765c48e66c9a0a7d70f6e4b0af00494c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00022_png.rf.783465f75a2393c7aaa0ec3c3cd3ed4d.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00027_png.rf.dfb965799faeb1514f927e69c5ec0fd2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00028_png.rf.f6f0a58dd52d1cf0fe75c8496a37b067.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00036_png.rf.a4fcf0fd896e50b389c7a93fae4d3a07.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00095_png.rf.7339640275f9c4483536f89fb2c815e0.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00100_png.rf.683a106328c4647fb8dcd00c1c2af90f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00104_png.rf.4b7fdfa8ad94152180492a204dfd629d.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00142_png.rf.def6aeee07cff082ea33cd3d659e7024.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00150_png.rf.59de5a3cfa738990cf21ba7d18b79444.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00151_png.rf.ff1355b3e842019c0228380552ea0c2c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00153_png.rf.19444df592470cf02432f62dfd784f12.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00154_png.rf.be661e0bba8aead34dbcded1d4e5b260.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00315_png.rf.14c625eca5ff0f371a2459cb470b6dd5.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00382_png.rf.da9f23f9bb25ab0a204cb881a5ccf798.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00600_png.rf.99bc40dcb86cb45b4425a2604dd3cd8d.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00615_png.rf.6b8b9a4df61e83d15119053ea613f434.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\FisheyeCamera_1_00922_png.rf.408835a278b9c700eb1a2f358ca58d07.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road104_png.rf.4468adcd7c2dcfc04377146de785c0a6.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road108_png.rf.9655ebb7a27af56ab1d0360d10685ec8.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road112_png.rf.b765c2b5d3a2145d317b0ceadfb08464.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road367_png.rf.68facda4326805592fce6d2bfb2dba6c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road388_png.rf.cc49d1d1343172eaa95da35bf070a7d3.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road393_png.rf.4fe43a89433923b9841d1435d98c4aae.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road397_png.rf.64b46468e2e241a3cb5dbce555894da3.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road400_png.rf.03186a0125d7e8f9ccbad9322201c91a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road402_png.rf.8b57601c39d08578c3fba71d26f6dd1a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road412_png.rf.f3dc3c3dcb2d0a679c190b33c3a3178b.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road420_png.rf.4db7dbd13a7b9c37ddddb7df9adf0834.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road421_png.rf.cd6d5f5724ac207f49f64d2ecc32f9f6.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road422_png.rf.9b9d58bbb154a5b030ff2addac608ef8.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road431_png.rf.4cf451707a1af9d139094513881b7654.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road439_png.rf.3a8f1ca30bf60d80f05733e8d83212d9.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road446_png.rf.f38afaa2d572c8426b05a88bdb4a5d3d.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road450_png.rf.4066ba8e8ac659692b69cbcf144c575f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road453_png.rf.2ac6332c02e34b01f38bd0daf2dee199.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road613_png.rf.560c13a685d02ca31a65b6b2b172772a.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road629_png.rf.79a049eae4f765c580544c533220d5f5.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road639_png.rf.74306332af06fee257b44f5dd9ae02fb.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road640_png.rf.d095777d03f03f86a0b6b1f5b32dfdd5.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road650_png.rf.b4086d2eec2b5bfe4465ae484a3b762f.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road666_png.rf.7d914d9d62e7d0fcc23d5bce18bb5d3c.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road691_png.rf.3ca3931933e5623e51596577124c3447.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road692_png.rf.428a4cfb2f374f0acb60ffc5c57e0750.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road701_png.rf.cdb390be5b29eb46e8125d30c802cde0.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road708_png.rf.d9bf7da6e0e73af3295909a18a2cabee.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road709_png.rf.4247ab0b03caf6c144ac9d5203850b81.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road716_png.rf.b9085b6c292ddd763a6e1481465dd3cd.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road743_png.rf.09b77e4a47a21b7c3482c28b37c86ecb.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road747_png.rf.66031af78137deac5c6878292d9ce7db.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road760_png.rf.cb25cb1c5c71e6bbf07a9dc3b11915d2.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road773_png.rf.b467561d9bc1abfaa69c770187f44c38.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road774_png.rf.01952886ddecdd8280c5df688e7f3f0e.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road794_png.rf.3569e6160a38765029861dd0a34ebfdd.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road803_png.rf.ec1de6db189d7a63e98b91529236a7d1.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road804_png.rf.c07a9b7b679e771fad740f296ee3a8f7.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road811_png.rf.e8ae9aefbf35658164ee88a52ed39bd8.txt
# Deleted file (all lines matched delete_classes): ./origindata/test/labels\road865_png.rf.d20a4a3f4030905929c2739f03eba9b8.txt
# Class Counts by Index: {'red': 516, 'yellow': 0, 'green': 494, 'stop_sign': 410, '40_sign': 315, '80_sign': 427, 'start_sign': 0, 'person': 0, 'others': 0}

# %%
import os
from collections import Counter

paths = ["./data/valid/", "./data/train/", "./data/test/"]

# 카테고리 정의 (주어진 순서대로)
categories = ["red", "yellow", "green", "stop_sign", "40_sign", "80_sign", "start_sign", "person", "others"]

# 출력 결과를 저장할 파일 경로
output_file = "category_counts.txt"

# 파일에 기록 시작
with open(output_file, "w") as out_file:
    total = 0  # 전체 총합을 저장할 변수

    for path in paths:
        # 폴더 경로 설정
        labels_folder = path + "labels"
        index_counter = Counter()  # 경로마다 카운터 초기화

        # labels 폴더에서 모든 txt 파일을 순회
        for filename in os.listdir(labels_folder):
            if filename.endswith(".txt"):
                txt_path = os.path.join(labels_folder, filename)

                # txt 파일 읽기
                with open(txt_path, "r") as file:
                    lines = file.readlines()
                    for line in lines:
                        parts = line.strip().split()
                        if parts:  # 비어 있지 않은 라인만 처리
                            first_index = parts[0]
                            if first_index.isdigit():
                                first_index = int(first_index)
                                if 0 <= first_index < len(categories) - 1:  # 마지막 인덱스는 "others"
                                    index_counter[categories[first_index]] += 1
                                    total += 1  # 카운트 합계에 추가
                                else:
                                    index_counter["others"] += 1  # 범위를 벗어난 값은 "others"로 분류
                                    total += 1  # 카운트 합계에 추가

        # 경로별 카운트 결과 작성 및 출력
        print(f"{path}'s Category Counts:")
        out_file.write(f"{path}'s Category Counts:\n")
        for category in categories:
            count = index_counter.get(category, 0)
            print(f"{category}: {count}")
            out_file.write(f"{category}: {count}\n")
        print("")  # 경로별 결과 간격 추가
        out_file.write("\n")

    # 총합 작성 및 출력
    print(f"Total Count: {total}")
    out_file.write(f"Total Count: {total}\n")

print(f"Results have been saved to {output_file}")
# Out:
# ./data/valid/'s Category Counts:
# red: 108
# yellow: 0
# green: 122
# stop_sign: 81
# 40_sign: 55
# 80_sign: 56
# start_sign: 0
# person: 0
# others: 0
#
# ./data/train/'s Category Counts:
# red: 585
# yellow: 0
# green: 542
# stop_sign: 285
# 40_sign: 235
# 80_sign: 323
# start_sign: 0
# person: 0
# others: 0
#
# ./data/test/'s Category Counts:
# red: 94
# yellow: 0
# green: 110
# stop_sign: 50
# 40_sign: 53
# 80_sign: 61
# start_sign: 0
# person: 0
# others: 0
#
# Total Count: 2760
# Results have been saved to category_counts.txt
